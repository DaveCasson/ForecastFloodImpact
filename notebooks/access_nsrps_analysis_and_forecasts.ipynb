# %% [markdown]
# ## Access NSRPS Analysis and Forecasts
#
# This notebook is used access hydrological data from the Meterological Services Canada WSC Service.
# This is includes:
# - Retrieving model analysis
# - Retrieving deterministic model results
# - Retrieving ensemble model results
#
# It was developed using helpful, open access information provided by [NHS NSRPS Streamflow Tutorials](https://github.com/NHS-Dev/geomet-nsrps-streamflow-tutorials/).

# %%
import configparser
import xarray as xr 
import pandas as pd
from pathlib import Path
import yaml

# Import local scripts
import sys
sys.path.append('../scripts')
from nsrps_data_access import query_wms_service_for_forecast_times, query_wms_service_for_analysis_times, query_wcs_service_for_forecast_data,query_wcs_service_for_analysis_data, extract_station_from_grid
from plot_hydrographs import plot_forecast_hydrograph_with_historical_ranges
# Set up logger
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

#Suppress info from matplotlib
logging.getLogger('matplotlib.category').disabled = True

# add autoreload to automatically reload modules when they change
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Read settings

# %%
config_file = "../settings/general_settings.yaml"

# Read settings from yaml file
with open(config_file, 'r') as ymlfile:
    config = yaml.load(ymlfile, Loader=yaml.FullLoader)

# Set variables, this can be replaced by a config file. To be discussed
api_url = config['msc_open_data_settings']['api_url']

# Set up paths 
gis_data_dir = config['paths']['gis_data']
output_base_dir = Path(config['paths']['output_dir'])
output_base_dir.mkdir(parents=True, exist_ok=True)

# Set up paths to gis data
stations_csv = Path(gis_data_dir, config['gis_data']['hydro_stns_csv'])
nsrps_station_location_csv = Path(gis_data_dir, config['gis_data']['nsrps_stns_csv'])

# %% [markdown]
# ### Read in login settings

# %%
# loading login information
login_config = configparser.ConfigParser()
login_config.read_file(open('../settings/config.cfg')) 

login = login_config['Login']

# %% [markdown]
# ### Retrieve Deterministic Forecast

# %%
layer_name = 'DHPS_1km_RiverDischarge'
output_dir = Path(output_base_dir, f'{layer_name}')
output_dir.mkdir(exist_ok=True)

newest_fcast, fcasthrs = query_wms_service_for_forecast_times(layer_name, login)
forecast_ds = query_wcs_service_for_forecast_data(layer_name, login, newest_fcast, fcasthrs)

forecast_ds.to_netcdf(Path(output_dir,f'{newest_fcast}.nc'))
# Out:
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-28T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T12:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-29T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T12:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-30T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T12:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-01-31T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T12:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-01T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T12:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T13:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T14:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T15:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T16:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T17:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T18:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T19:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T20:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T21:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T22:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-02T23:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T00:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T01:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T02:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T03:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T04:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T05:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T06:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T07:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T08:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T09:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T10:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T11:00:00Z
# INFO:nsrps_data_access:Querying 2024-01-28T12:00:00Zm lead time 2024-02-03T12:00:00Z

# %%
# Read in the list of hydrometric stations
nsrps_station_locations_df = pd.read_csv(nsrps_station_location_csv)
hydro_stations_df = pd.read_csv(stations_csv)

search_stations = hydro_stations_df["ID"].tolist()

# Extract the stations that are in the Bow watershed
nsrps_stations = nsrps_station_locations_df[nsrps_station_locations_df['STATION_NUMBER'].isin(search_stations)]

# %%
forecast_ds = xr.open_dataset(Path(output_dir,f'{newest_fcast}.nc'))

for station in nsrps_stations.iterrows():

    station_data = extract_station_from_grid(station, forecast_ds)
    station_data_df = station_data.to_dataframe()
    station_data_df.rename(columns={'Band1':'Discharge'}, inplace=True)

    station_data_df.to_csv(f'{output_dir}/{station[1]["STATION_NUMBER"]}_forecast.csv')

# %%
layer_name = 'DHPS-Analysis_1km_RiverDischarge'
output_dir = Path(output_base_dir, f'{layer_name}')
output_dir.mkdir(exist_ok=True)

analysis_time = query_wms_service_for_analysis_times(layer_name, login)

analysis_ds = query_wcs_service_for_analysis_data(layer_name, login,analysis_time)

analysis_ds.to_netcdf(Path(output_dir,f'{analysis_time}.nc'))

for station in nsrps_stations.iterrows():

    station_data = extract_station_from_grid(station, analysis_ds)
    station_data_df = station_data.to_dataframe()
    station_data_df.rename(columns={'Band1':'Discharge'}, inplace=True)
    station_data_df.to_csv(f'{output_dir}/{station[1]["STATION_NUMBER"]}_analysis.csv')

# %%
variable = 'LEVEL'

real_time_level_stations = ['05BH015']
historic_level_stations = ['05BH015']


#print(f'Real time stations with {variable} data: {real_time_discharge_stations}')

for station_id in real_time_level_stations:
    if station_id not in historic_level_stations:
        continue
    
    historic_df = pd.read_csv(f'{output_dir}/hydrometric-daily-mean/{station_id}_{variable}.csv')
    realtime_df = pd.read_csv(f'{output_dir}/hydrometric-realtime/{station_id}_{variable}.csv')
    analysis_df = pd.read_csv(f'{output_dir}/DHPS-Analysis_1km_RiverDischarge/{station_id}_analysis.csv')
    forecast_df = pd.read_csv(f'{output_dir}/DHPS_1km_RiverDischarge/{station_id}_forecast.csv')
    png_path = f'{output_dir}/{station_id}_{variable}_forecast_hydrograph.png'

    plot_forecast_hydrograph_with_historical_ranges(station_id,variable, historic_df, realtime_df,analysis_df,forecast_df, save_png=True, png_path=png_path)
